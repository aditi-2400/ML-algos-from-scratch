# %% [markdown]
# # Batch Gradient Descent

# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py
import json
from sklearn.model_selection import train_test_split

# %%
#Extracting x and y data
with h5py.File('mnist_testdata.hdf5', 'r') as hf:
    xdata = hf['xdata'][:]
    ydata = hf['ydata'][:]

# %%
xdata.shape
# Out:
# (10000, 784)

# %%
ydata.shape
# Out:
# (10000, 10)

# %%
def softmax(X):
    exp_X = np.exp(X - np.max(X, axis=-1, keepdims=True))
    return exp_X / np.sum(exp_X, axis=-1, keepdims=True)

# %%
def init(xdata):
    n_samples, n_features = xdata.shape
    classes = 10
    init_weights = np.random.randn(n_features,classes)
    init_bias = np.random.randn(classes)
    return init_weights,init_bias

# %%
def feed_forward(X,weights,bias):
    a = np.dot(X,weights) + bias
    yhat = softmax(a)
    return yhat

# %%
def compute_loss(y_label,y_pred):
    epsilon = 1e-9   #to avoid log0 calculations
    y = np.sum(y_label*np.log(y_pred + epsilon),axis=1)
    return -np.mean(y)

# %%
def compute_accuracy(y_label,y_pred):
    y_true = np.argmax(y_label, axis=1)
    accuracy = np.mean(y_true == y_pred)
    return accuracy

# %%
def fit(x_train,y_train,x_test,y_test,lr,epochs):
    weights,bias = init(x_train)
    train_loss = []
    test_loss = []
    train_accuracy = []
    test_accuracy = []
    total_operations = 0
    for epoch in range(epochs):
        softmax_train = np.zeros(x_test.shape)
        softmax_test = np.zeros(y_test.shape)
        train_pred = np.zeros(x_train.shape[0])  # Initialize as NumPy array
        test_pred = np.zeros(x_test.shape[0])
        for i in range(x_train.shape[0]):
            yhat = feed_forward(x_train[i],weights,bias)
            total_operations += x_train.shape[1] + yhat.size
            dw = np.outer(x_train[i],(y_train[i] - yhat)) 
            db = (y_train[i] - yhat)
            total_operations += (x_train.shape[1] * yhat.size) + yhat.size
            weights += lr * dw
            bias += lr * db
        for j in range(x_train.shape[0]):
            softmax_train = feed_forward(x_train[j],weights,bias)
            train_pred[j] = np.argmax(softmax_train)
        loss1 = compute_loss(y_train,softmax_train)
        accuracy1 = compute_accuracy(y_train,train_pred)
        train_loss.append(loss1)
        train_accuracy.append(accuracy1)
        for i in range(x_test.shape[0]):
            softmax_test = feed_forward(x_test[i],weights,bias)
            test_pred[i] = np.argmax(softmax_test)
        loss2 = compute_loss(y_test,softmax_test)
        accuracy2 = compute_accuracy(y_test,test_pred)
        test_loss.append(loss2)
        test_accuracy.append(accuracy2)
        total_operations += (y_train.shape[1] * softmax_train.shape[0])  # For training loss
        total_operations += (y_test.shape[1] * softmax_test.shape[0])    # For testing loss
        print(f'Epoch {epoch+1}/{epochs} => Train Loss: {loss1:.4f}, Test Loss: {loss2:.4f}, Train Accuracy: {accuracy1:.4f}, Test Accuracy: {accuracy2:.4f}')
    print(f'Total operations: {total_operations}')  # Print the total operations
    return weights,bias,train_loss,test_loss,train_accuracy,test_accuracy

# %%
x_train, x_test, y_train, y_test = train_test_split(xdata, ydata, test_size=0.3, random_state=15)
x_train.shape
# Out:
# (7000, 784)

# %%
y_train.shape
# Out:
# (7000, 10)

# %%
weights,bias,train_loss,test_loss,train_accuracy,test_accuracy = fit(x_train,y_train,x_test,y_test,0.01,20)
# Out:
# Epoch 1/20 => Train Loss: 15.1494, Test Loss: 11.0385, Train Accuracy: 0.7961, Test Accuracy: 0.7697
# Epoch 2/20 => Train Loss: 15.5868, Test Loss: 10.1747, Train Accuracy: 0.8466, Test Accuracy: 0.8117
# Epoch 3/20 => Train Loss: 15.6054, Test Loss: 9.8753, Train Accuracy: 0.8666, Test Accuracy: 0.8390
# Epoch 4/20 => Train Loss: 15.5895, Test Loss: 9.7812, Train Accuracy: 0.8814, Test Accuracy: 0.8483
# Epoch 5/20 => Train Loss: 15.4977, Test Loss: 9.7044, Train Accuracy: 0.8907, Test Accuracy: 0.8520
# Epoch 6/20 => Train Loss: 15.3531, Test Loss: 9.6245, Train Accuracy: 0.8991, Test Accuracy: 0.8560
# Epoch 7/20 => Train Loss: 15.2002, Test Loss: 9.5552, Train Accuracy: 0.9043, Test Accuracy: 0.8620
# Epoch 8/20 => Train Loss: 15.0520, Test Loss: 9.5048, Train Accuracy: 0.9074, Test Accuracy: 0.8617
# Epoch 9/20 => Train Loss: 14.9111, Test Loss: 9.4687, Train Accuracy: 0.9110, Test Accuracy: 0.8650
# Epoch 10/20 => Train Loss: 14.7758, Test Loss: 9.4382, Train Accuracy: 0.9144, Test Accuracy: 0.8673
# Epoch 11/20 => Train Loss: 14.6441, Test Loss: 9.4073, Train Accuracy: 0.9173, Test Accuracy: 0.8687
# Epoch 12/20 => Train Loss: 14.5169, Test Loss: 9.3731, Train Accuracy: 0.9200, Test Accuracy: 0.8697
# Epoch 13/20 => Train Loss: 14.3971, Test Loss: 9.3354, Train Accuracy: 0.9220, Test Accuracy: 0.8713
# Epoch 14/20 => Train Loss: 14.2881, Test Loss: 9.2960, Train Accuracy: 0.9253, Test Accuracy: 0.8717
# Epoch 15/20 => Train Loss: 14.1920, Test Loss: 9.2573, Train Accuracy: 0.9270, Test Accuracy: 0.8733
# Epoch 16/20 => Train Loss: 14.1097, Test Loss: 9.2212, Train Accuracy: 0.9286, Test Accuracy: 0.8747
# Epoch 17/20 => Train Loss: 14.0408, Test Loss: 9.1891, Train Accuracy: 0.9309, Test Accuracy: 0.8760
# Epoch 18/20 => Train Loss: 13.9845, Test Loss: 9.1623, Train Accuracy: 0.9319, Test Accuracy: 0.8753
# Epoch 19/20 => Train Loss: 13.9396, Test Loss: 9.1425, Train Accuracy: 0.9333, Test Accuracy: 0.8763
# Epoch 20/20 => Train Loss: 13.9043, Test Loss: 9.1309, Train Accuracy: 0.9343, Test Accuracy: 0.8757
# Total operations: 1210164000

# %%
#plotting the training and testing loss
epoch = [i for i in range(1,21,1)]
plt.plot(epoch,train_loss ,marker='o', label='train_log_loss')
plt.plot(epoch,test_loss, marker='x', label='test_log_loss')
plt.xlabel("epoch number")
plt.ylabel("log loss")
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(range(len(train_accuracy)), train_accuracy, marker='o', label='Training Accuracy')
plt.plot(range(len(test_accuracy)), test_accuracy, marker='x', label='Test Accuracy')
plt.xlabel('Iterations')
plt.ylabel('Accuracy')
plt.title('Training and Test Accuracy vs Iterations')
plt.legend()
plt.show()

# %% [markdown]
# # Stochastic Gradient Descent: Mini Batch size = 1

# %%
def sgd_fit(x_train,y_train,x_test,y_test,lr,epochs):
    weights,bias = init(x_train)
    train_loss = []
    test_loss = []
    train_accuracy = []
    test_accuracy = []
    total_operations = 0
    for epoch in range(epochs):
            #softmax_train = np.zeros(x_test.shape)
            #softmax_test = np.zeros(y_test.shape)
            #train_pred = np.zeros(x_train.shape[0])  # Initialize as NumPy array
            #test_pred = np.zeros(x_test.shape[0])
        for i in range(x_train.shape[0]):
            yhat = feed_forward(x_train[i],weights,bias)
            total_operations += x_train.shape[1] + yhat.size
            dw = np.outer(x_train[i],(y_train[i] - yhat)) 
            db = (y_train[i] - yhat)
            total_operations += x_train.shape[1] * yhat.size  # Operations for dw
            total_operations += yhat.size  # Operations for db
            weights += lr * dw
            bias += lr * db
            if (epoch * x_train.shape[0] + i + 1) % 5000 == 0:
                train_pred = np.zeros(x_train.shape[0])
                for j in range(x_train.shape[0]):
                    softmax_train = feed_forward(x_train[j],weights,bias)
                    train_pred[j] = np.argmax(softmax_train)
                loss1 = compute_loss(y_train,softmax_train)
                accuracy1 = compute_accuracy(y_train,train_pred)
                train_loss.append(loss1)
                train_accuracy.append(accuracy1)
                test_pred = np.zeros(x_test.shape[0])
                for i in range(x_test.shape[0]):
                    softmax_test = feed_forward(x_test[i],weights,bias)
                    test_pred[i] = np.argmax(softmax_test)
                loss2 = compute_loss(y_test,softmax_test)
                accuracy2 = compute_accuracy(y_test,test_pred)
                test_loss.append(loss2)
                test_accuracy.append(accuracy2)
                total_operations += (y_train.shape[1] * softmax_train.shape[0])  # For loss
                total_operations += y_train.shape[0]  # For accuracy calculation
                print(f'Epoch {epoch + 1}, Sample {epoch * x_train.shape[0] + i + 1} => Train Loss: {loss1:.4f}, Test Loss: {loss2:.4f}, Train Accuracy: {accuracy1:.4f}, Test Accuracy: {accuracy2:.4f}')
    print(f'Total operations: {total_operations}')  # Print the total operations
    batch_numbers = [0] + [(epoch * x_train.shape[0] + i + 1) // 5000 for epoch in range(epochs) for i in range(x_train.shape[0]) if (epoch * x_train.shape[0] + i + 1) % 5000 == 0]
    return weights,bias,train_loss,test_loss,train_accuracy,test_accuracy,batch_numbers

# %%
weights_sgd,bias_sgd,train_loss_sgd,test_loss_sgd,train_accuracy_sgd,test_accuracy_sgd,batch_numbers = sgd_fit(x_train,y_train,x_test,y_test,0.01,20)
# Out:
# Epoch 1, Sample 3000 => Train Loss: 13.0016, Test Loss: 10.6441, Train Accuracy: 0.7549, Test Accuracy: 0.7277
# Epoch 2, Sample 10000 => Train Loss: 13.3274, Test Loss: 8.8731, Train Accuracy: 0.8149, Test Accuracy: 0.7893
# Epoch 3, Sample 17000 => Train Loss: 13.6508, Test Loss: 10.2138, Train Accuracy: 0.8471, Test Accuracy: 0.8283
# Epoch 3, Sample 17000 => Train Loss: 14.4248, Test Loss: 11.7281, Train Accuracy: 0.8641, Test Accuracy: 0.8390
# Epoch 4, Sample 24000 => Train Loss: 14.0892, Test Loss: 10.1270, Train Accuracy: 0.8714, Test Accuracy: 0.8370
# Epoch 5, Sample 31000 => Train Loss: 13.9681, Test Loss: 10.1573, Train Accuracy: 0.8819, Test Accuracy: 0.8507
# Epoch 5, Sample 31000 => Train Loss: 14.5033, Test Loss: 10.4319, Train Accuracy: 0.8873, Test Accuracy: 0.8513
# Epoch 6, Sample 38000 => Train Loss: 14.1657, Test Loss: 9.2378, Train Accuracy: 0.8979, Test Accuracy: 0.8620
# Epoch 7, Sample 45000 => Train Loss: 13.9610, Test Loss: 7.9819, Train Accuracy: 0.9024, Test Accuracy: 0.8553
# Epoch 8, Sample 52000 => Train Loss: 13.6270, Test Loss: 8.7411, Train Accuracy: 0.9043, Test Accuracy: 0.8627
# Epoch 8, Sample 52000 => Train Loss: 14.0609, Test Loss: 9.5327, Train Accuracy: 0.9104, Test Accuracy: 0.8640
# Epoch 9, Sample 59000 => Train Loss: 14.0062, Test Loss: 8.2616, Train Accuracy: 0.9074, Test Accuracy: 0.8573
# Epoch 10, Sample 66000 => Train Loss: 13.6627, Test Loss: 8.7364, Train Accuracy: 0.9131, Test Accuracy: 0.8673
# Epoch 10, Sample 66000 => Train Loss: 14.1090, Test Loss: 9.1175, Train Accuracy: 0.9141, Test Accuracy: 0.8623
# Epoch 11, Sample 73000 => Train Loss: 13.9400, Test Loss: 7.6239, Train Accuracy: 0.9224, Test Accuracy: 0.8713
# Epoch 12, Sample 80000 => Train Loss: 13.9892, Test Loss: 7.0680, Train Accuracy: 0.9233, Test Accuracy: 0.8663
# Epoch 13, Sample 87000 => Train Loss: 13.5184, Test Loss: 7.7157, Train Accuracy: 0.9249, Test Accuracy: 0.8710
# Epoch 13, Sample 87000 => Train Loss: 13.8042, Test Loss: 8.3483, Train Accuracy: 0.9277, Test Accuracy: 0.8697
# Epoch 14, Sample 94000 => Train Loss: 13.8565, Test Loss: 7.4226, Train Accuracy: 0.9221, Test Accuracy: 0.8640
# Epoch 15, Sample 101000 => Train Loss: 13.5501, Test Loss: 7.8121, Train Accuracy: 0.9283, Test Accuracy: 0.8723
# Epoch 15, Sample 101000 => Train Loss: 13.8274, Test Loss: 7.9471, Train Accuracy: 0.9291, Test Accuracy: 0.8717
# Epoch 16, Sample 108000 => Train Loss: 13.7121, Test Loss: 7.1044, Train Accuracy: 0.9339, Test Accuracy: 0.8750
# Epoch 17, Sample 115000 => Train Loss: 13.8684, Test Loss: 7.0006, Train Accuracy: 0.9330, Test Accuracy: 0.8730
# Epoch 18, Sample 122000 => Train Loss: 13.4557, Test Loss: 7.3558, Train Accuracy: 0.9351, Test Accuracy: 0.8757
# Epoch 18, Sample 122000 => Train Loss: 13.5786, Test Loss: 7.8882, Train Accuracy: 0.9359, Test Accuracy: 0.8760
# Epoch 19, Sample 129000 => Train Loss: 13.7071, Test Loss: 7.5882, Train Accuracy: 0.9320, Test Accuracy: 0.8687
# Epoch 20, Sample 136000 => Train Loss: 13.4608, Test Loss: 7.8242, Train Accuracy: 0.9370, Test Accuracy: 0.8760
# Epoch 20, Sample 136000 => Train Loss: 13.6017, Test Loss: 7.7084, Train Accuracy: 0.9391, Test Accuracy: 0.8777
# Total operations: 1210358800

# %%
plt.plot(batch_numbers[1:], train_loss_sgd, marker='o', label='Train Loss')
plt.plot(batch_numbers[1:], test_loss_sgd, marker='x', label='Test Loss')
plt.title('Log-Loss vs. Batch Number')
plt.xlabel('Batch Number')
plt.ylabel('Log-Loss')
plt.legend()
plt.show()

# %%
plt.plot(batch_numbers[1:], train_accuracy_sgd, marker='o', label='Train Accuracy')
plt.plot(batch_numbers[1:], test_accuracy_sgd, marker='x', label='Test Accuracy')
plt.title('Accuracy vs. Batch Number')
plt.xlabel('Batch Number')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# #Stochastic Gradient Descent: Mini Batch size = 100

# %%
def mini_batch_fit(x_train,y_train,x_test,y_test,lr,epochs,batch_size):
    weights,bias = init(x_train)
    train_loss = []
    test_loss = []
    train_accuracy = []
    test_accuracy = []
    total_operations = 0
    num_classes = y_train.shape[1] 
    for epoch in range(epochs):
        indices = np.random.permutation(x_train.shape[0])
        softmax_train = np.zeros((x_train.shape[0], num_classes))
        softmax_test = np.zeros((x_test.shape[0], num_classes))
        #train_pred = np.zeros(x_train.shape[0])  # Initialize as NumPy array
        #test_pred = np.zeros(x_test.shape[0])
        for i in range(0,x_train.shape[0],batch_size):
            batch_indices = indices[i:i + batch_size]
            x_batch = x_train[batch_indices]
            y_batch = y_train[batch_indices]
            #initialize gradients
            dw = np.zeros_like(weights)
            db = np.zeros_like(bias)
            for j in range(x_batch.shape[0]):
                yhat = feed_forward(x_batch[j],weights,bias)
                dw += np.outer(x_batch[j],(y_batch[j] - yhat))    #accumulating gradients
                db += (y_batch[j] - yhat)
            # Average the gradients
            dw /= x_batch.shape[0]
            db /= x_batch.shape[0]
            #update the weights
            weights += lr * dw
            bias += lr * db
            total_operations += (x_batch.shape[0] * (x_batch.shape[1] + num_classes))  # D + C
            # Loss and gradient calculations
            total_operations += (x_batch.shape[0] * (num_classes + x_batch.shape[1] * num_classes))  # Loss + gradient
            if (epoch * x_train.shape[0] + i + batch_size) % 5000 == 0:
                train_pred = np.zeros(x_train.shape[0])
                for j in range(x_train.shape[0]):
                    softmax_train[j] = feed_forward(x_train[j],weights,bias)
                    train_pred[j] = np.argmax(softmax_train[j])
                loss1 = compute_loss(y_train,softmax_train)
                accuracy1 = compute_accuracy(y_train,train_pred)
                train_loss.append(loss1)
                train_accuracy.append(accuracy1)
                test_pred = np.zeros(x_test.shape[0])
                for i in range(x_test.shape[0]):
                    softmax_test[i] = feed_forward(x_test[i],weights,bias)
                    test_pred[i] = np.argmax(softmax_test[i])
                loss2 = compute_loss(y_test,softmax_test)
                accuracy2 = compute_accuracy(y_test,test_pred)
                test_loss.append(loss2)
                test_accuracy.append(accuracy2)
                current_batch = (epoch * x_train.shape[0] + i + batch_size) // batch_size
                print(f'Epoch {epoch + 1}, (Batch {current_batch}), Sample {epoch * x_train.shape[0] + i + batch_size} => Train Loss: {loss1:.4f}, Test Loss: {loss2:.4f}, Train Accuracy: {accuracy1:.4f}, Test Accuracy: {accuracy2:.4f}')
    #batch_numbers = [0] + [(epoch * x_train.shape[0] + i + 1) // 5000 for epoch in range(epochs) for i in range(x_train.shape[0]) if (epoch * x_train.shape[0] + i + 1) % 5000 == 0]
    print(f'Total operations to reach comparable performance: {total_operations}')
    return weights,bias,train_loss,test_loss,train_accuracy,test_accuracy

# %%
weights_minib,bias_minib,train_loss_minib,test_loss_minib,train_accuracy_minib,test_accuracy_minib = mini_batch_fit(x_train,y_train,x_test,y_test,0.1,100,100)
# Out:
# Epoch 1, (Batch 30), Sample 3099 => Train Loss: 4.9524, Test Loss: 5.1476, Train Accuracy: 0.3229, Test Accuracy: 0.3083
# Epoch 2, (Batch 100), Sample 10099 => Train Loss: 3.2988, Test Loss: 3.5093, Train Accuracy: 0.4710, Test Accuracy: 0.4483
# Epoch 3, (Batch 170), Sample 17099 => Train Loss: 2.5274, Test Loss: 2.7419, Train Accuracy: 0.5656, Test Accuracy: 0.5387
# Epoch 3, (Batch 170), Sample 17099 => Train Loss: 2.0952, Test Loss: 2.3034, Train Accuracy: 0.6159, Test Accuracy: 0.5923
# Epoch 4, (Batch 240), Sample 24099 => Train Loss: 1.8233, Test Loss: 2.0213, Train Accuracy: 0.6594, Test Accuracy: 0.6357
# Epoch 5, (Batch 310), Sample 31099 => Train Loss: 1.6238, Test Loss: 1.8272, Train Accuracy: 0.6909, Test Accuracy: 0.6633
# Epoch 5, (Batch 310), Sample 31099 => Train Loss: 1.4789, Test Loss: 1.6694, Train Accuracy: 0.7114, Test Accuracy: 0.6803
# Epoch 6, (Batch 380), Sample 38099 => Train Loss: 1.3696, Test Loss: 1.5625, Train Accuracy: 0.7314, Test Accuracy: 0.7040
# Epoch 7, (Batch 450), Sample 45099 => Train Loss: 1.2838, Test Loss: 1.4678, Train Accuracy: 0.7431, Test Accuracy: 0.7190
# Epoch 8, (Batch 520), Sample 52099 => Train Loss: 1.2157, Test Loss: 1.4105, Train Accuracy: 0.7546, Test Accuracy: 0.7300
# Epoch 8, (Batch 520), Sample 52099 => Train Loss: 1.1508, Test Loss: 1.3325, Train Accuracy: 0.7643, Test Accuracy: 0.7383
# Epoch 9, (Batch 590), Sample 59099 => Train Loss: 1.1003, Test Loss: 1.2877, Train Accuracy: 0.7729, Test Accuracy: 0.7493
# Epoch 10, (Batch 660), Sample 66099 => Train Loss: 1.0524, Test Loss: 1.2380, Train Accuracy: 0.7813, Test Accuracy: 0.7543
# Epoch 10, (Batch 660), Sample 66099 => Train Loss: 1.0128, Test Loss: 1.1929, Train Accuracy: 0.7886, Test Accuracy: 0.7663
# Epoch 11, (Batch 730), Sample 73099 => Train Loss: 0.9768, Test Loss: 1.1599, Train Accuracy: 0.7959, Test Accuracy: 0.7687
# Epoch 12, (Batch 800), Sample 80099 => Train Loss: 0.9459, Test Loss: 1.1313, Train Accuracy: 0.8020, Test Accuracy: 0.7760
# Epoch 13, (Batch 870), Sample 87099 => Train Loss: 0.9168, Test Loss: 1.1039, Train Accuracy: 0.8074, Test Accuracy: 0.7810
# Epoch 13, (Batch 870), Sample 87099 => Train Loss: 0.8911, Test Loss: 1.0787, Train Accuracy: 0.8120, Test Accuracy: 0.7873
# Epoch 14, (Batch 940), Sample 94099 => Train Loss: 0.8672, Test Loss: 1.0554, Train Accuracy: 0.8150, Test Accuracy: 0.7903
# Epoch 15, (Batch 1010), Sample 101099 => Train Loss: 0.8451, Test Loss: 1.0361, Train Accuracy: 0.8206, Test Accuracy: 0.7977
# Epoch 15, (Batch 1010), Sample 101099 => Train Loss: 0.8257, Test Loss: 1.0129, Train Accuracy: 0.8230, Test Accuracy: 0.8010
# Epoch 16, (Batch 1080), Sample 108099 => Train Loss: 0.8064, Test Loss: 1.0000, Train Accuracy: 0.8257, Test Accuracy: 0.8040
# Epoch 17, (Batch 1150), Sample 115099 => Train Loss: 0.7914, Test Loss: 0.9911, Train Accuracy: 0.8289, Test Accuracy: 0.8053
# Epoch 18, (Batch 1220), Sample 122099 => Train Loss: 0.7736, Test Loss: 0.9700, Train Accuracy: 0.8311, Test Accuracy: 0.8083
# Epoch 18, (Batch 1220), Sample 122099 => Train Loss: 0.7578, Test Loss: 0.9498, Train Accuracy: 0.8339, Test Accuracy: 0.8130
# Epoch 19, (Batch 1290), Sample 129099 => Train Loss: 0.7432, Test Loss: 0.9410, Train Accuracy: 0.8351, Test Accuracy: 0.8130
# Epoch 20, (Batch 1360), Sample 136099 => Train Loss: 0.7311, Test Loss: 0.9296, Train Accuracy: 0.8387, Test Accuracy: 0.8137
# Epoch 20, (Batch 1360), Sample 136099 => Train Loss: 0.7173, Test Loss: 0.9126, Train Accuracy: 0.8413, Test Accuracy: 0.8193
# Epoch 21, (Batch 1430), Sample 143099 => Train Loss: 0.7061, Test Loss: 0.9056, Train Accuracy: 0.8430, Test Accuracy: 0.8210
# Epoch 22, (Batch 1500), Sample 150099 => Train Loss: 0.6962, Test Loss: 0.9024, Train Accuracy: 0.8449, Test Accuracy: 0.8177
# Epoch 23, (Batch 1570), Sample 157099 => Train Loss: 0.6846, Test Loss: 0.8825, Train Accuracy: 0.8459, Test Accuracy: 0.8223
# Epoch 23, (Batch 1570), Sample 157099 => Train Loss: 0.6720, Test Loss: 0.8777, Train Accuracy: 0.8500, Test Accuracy: 0.8227
# Epoch 24, (Batch 1640), Sample 164099 => Train Loss: 0.6630, Test Loss: 0.8695, Train Accuracy: 0.8514, Test Accuracy: 0.8240
# Epoch 25, (Batch 1710), Sample 171099 => Train Loss: 0.6557, Test Loss: 0.8673, Train Accuracy: 0.8541, Test Accuracy: 0.8223
# Epoch 25, (Batch 1710), Sample 171099 => Train Loss: 0.6439, Test Loss: 0.8520, Train Accuracy: 0.8553, Test Accuracy: 0.8277
# Epoch 26, (Batch 1780), Sample 178099 => Train Loss: 0.6359, Test Loss: 0.8488, Train Accuracy: 0.8566, Test Accuracy: 0.8287
# Epoch 27, (Batch 1850), Sample 185099 => Train Loss: 0.6274, Test Loss: 0.8360, Train Accuracy: 0.8573, Test Accuracy: 0.8320
# Epoch 28, (Batch 1920), Sample 192099 => Train Loss: 0.6199, Test Loss: 0.8278, Train Accuracy: 0.8594, Test Accuracy: 0.8313
# Epoch 28, (Batch 1920), Sample 192099 => Train Loss: 0.6107, Test Loss: 0.8259, Train Accuracy: 0.8596, Test Accuracy: 0.8297
# Epoch 29, (Batch 1990), Sample 199099 => Train Loss: 0.6033, Test Loss: 0.8157, Train Accuracy: 0.8619, Test Accuracy: 0.8343
# Epoch 30, (Batch 2060), Sample 206099 => Train Loss: 0.5970, Test Loss: 0.8151, Train Accuracy: 0.8639, Test Accuracy: 0.8340
# Epoch 30, (Batch 2060), Sample 206099 => Train Loss: 0.5903, Test Loss: 0.8051, Train Accuracy: 0.8641, Test Accuracy: 0.8377
# Epoch 31, (Batch 2130), Sample 213099 => Train Loss: 0.5833, Test Loss: 0.7977, Train Accuracy: 0.8670, Test Accuracy: 0.8413
# Epoch 32, (Batch 2200), Sample 220099 => Train Loss: 0.5770, Test Loss: 0.7965, Train Accuracy: 0.8670, Test Accuracy: 0.8397
# Epoch 33, (Batch 2270), Sample 227099 => Train Loss: 0.5704, Test Loss: 0.7848, Train Accuracy: 0.8681, Test Accuracy: 0.8413
# Epoch 33, (Batch 2270), Sample 227099 => Train Loss: 0.5637, Test Loss: 0.7849, Train Accuracy: 0.8686, Test Accuracy: 0.8403
# Epoch 34, (Batch 2340), Sample 234099 => Train Loss: 0.5573, Test Loss: 0.7834, Train Accuracy: 0.8710, Test Accuracy: 0.8413
# Epoch 35, (Batch 2410), Sample 241099 => Train Loss: 0.5510, Test Loss: 0.7723, Train Accuracy: 0.8723, Test Accuracy: 0.8440
# Epoch 35, (Batch 2410), Sample 241099 => Train Loss: 0.5462, Test Loss: 0.7716, Train Accuracy: 0.8716, Test Accuracy: 0.8427
# Epoch 36, (Batch 2480), Sample 248099 => Train Loss: 0.5414, Test Loss: 0.7696, Train Accuracy: 0.8726, Test Accuracy: 0.8420
# Epoch 37, (Batch 2550), Sample 255099 => Train Loss: 0.5353, Test Loss: 0.7634, Train Accuracy: 0.8754, Test Accuracy: 0.8457
# Epoch 38, (Batch 2620), Sample 262099 => Train Loss: 0.5315, Test Loss: 0.7596, Train Accuracy: 0.8757, Test Accuracy: 0.8447
# Epoch 38, (Batch 2620), Sample 262099 => Train Loss: 0.5256, Test Loss: 0.7569, Train Accuracy: 0.8749, Test Accuracy: 0.8453
# Epoch 39, (Batch 2690), Sample 269099 => Train Loss: 0.5203, Test Loss: 0.7498, Train Accuracy: 0.8769, Test Accuracy: 0.8480
# Epoch 40, (Batch 2760), Sample 276099 => Train Loss: 0.5167, Test Loss: 0.7480, Train Accuracy: 0.8766, Test Accuracy: 0.8457
# Epoch 40, (Batch 2760), Sample 276099 => Train Loss: 0.5107, Test Loss: 0.7442, Train Accuracy: 0.8783, Test Accuracy: 0.8477
# Epoch 41, (Batch 2830), Sample 283099 => Train Loss: 0.5063, Test Loss: 0.7387, Train Accuracy: 0.8790, Test Accuracy: 0.8487
# Epoch 42, (Batch 2900), Sample 290099 => Train Loss: 0.5015, Test Loss: 0.7359, Train Accuracy: 0.8803, Test Accuracy: 0.8483
# Epoch 43, (Batch 2970), Sample 297099 => Train Loss: 0.4986, Test Loss: 0.7309, Train Accuracy: 0.8801, Test Accuracy: 0.8490
# Epoch 43, (Batch 2970), Sample 297099 => Train Loss: 0.4948, Test Loss: 0.7305, Train Accuracy: 0.8826, Test Accuracy: 0.8493
# Epoch 44, (Batch 3040), Sample 304099 => Train Loss: 0.4890, Test Loss: 0.7259, Train Accuracy: 0.8823, Test Accuracy: 0.8503
# Epoch 45, (Batch 3110), Sample 311099 => Train Loss: 0.4869, Test Loss: 0.7284, Train Accuracy: 0.8841, Test Accuracy: 0.8513
# Epoch 45, (Batch 3110), Sample 311099 => Train Loss: 0.4813, Test Loss: 0.7194, Train Accuracy: 0.8831, Test Accuracy: 0.8513
# Epoch 46, (Batch 3180), Sample 318099 => Train Loss: 0.4773, Test Loss: 0.7159, Train Accuracy: 0.8857, Test Accuracy: 0.8520
# Epoch 47, (Batch 3250), Sample 325099 => Train Loss: 0.4748, Test Loss: 0.7170, Train Accuracy: 0.8864, Test Accuracy: 0.8513
# Epoch 48, (Batch 3320), Sample 332099 => Train Loss: 0.4711, Test Loss: 0.7173, Train Accuracy: 0.8876, Test Accuracy: 0.8500
# Epoch 48, (Batch 3320), Sample 332099 => Train Loss: 0.4664, Test Loss: 0.7090, Train Accuracy: 0.8876, Test Accuracy: 0.8530
# Epoch 49, (Batch 3390), Sample 339099 => Train Loss: 0.4627, Test Loss: 0.7074, Train Accuracy: 0.8894, Test Accuracy: 0.8527
# Epoch 50, (Batch 3460), Sample 346099 => Train Loss: 0.4601, Test Loss: 0.7088, Train Accuracy: 0.8890, Test Accuracy: 0.8540
# Epoch 50, (Batch 3460), Sample 346099 => Train Loss: 0.4569, Test Loss: 0.6995, Train Accuracy: 0.8890, Test Accuracy: 0.8540
# Epoch 51, (Batch 3530), Sample 353099 => Train Loss: 0.4523, Test Loss: 0.7001, Train Accuracy: 0.8896, Test Accuracy: 0.8550
# Epoch 52, (Batch 3600), Sample 360099 => Train Loss: 0.4508, Test Loss: 0.6996, Train Accuracy: 0.8913, Test Accuracy: 0.8550
# Epoch 53, (Batch 3670), Sample 367099 => Train Loss: 0.4460, Test Loss: 0.6944, Train Accuracy: 0.8926, Test Accuracy: 0.8550
# Epoch 53, (Batch 3670), Sample 367099 => Train Loss: 0.4428, Test Loss: 0.6942, Train Accuracy: 0.8927, Test Accuracy: 0.8537
# Epoch 54, (Batch 3740), Sample 374099 => Train Loss: 0.4410, Test Loss: 0.6900, Train Accuracy: 0.8916, Test Accuracy: 0.8540
# Epoch 55, (Batch 3810), Sample 381099 => Train Loss: 0.4376, Test Loss: 0.6894, Train Accuracy: 0.8931, Test Accuracy: 0.8550
# Epoch 55, (Batch 3810), Sample 381099 => Train Loss: 0.4338, Test Loss: 0.6873, Train Accuracy: 0.8946, Test Accuracy: 0.8570
# Epoch 56, (Batch 3880), Sample 388099 => Train Loss: 0.4314, Test Loss: 0.6862, Train Accuracy: 0.8956, Test Accuracy: 0.8577
# Epoch 57, (Batch 3950), Sample 395099 => Train Loss: 0.4289, Test Loss: 0.6876, Train Accuracy: 0.8964, Test Accuracy: 0.8560
# Epoch 58, (Batch 4020), Sample 402099 => Train Loss: 0.4265, Test Loss: 0.6826, Train Accuracy: 0.8963, Test Accuracy: 0.8563
# Epoch 58, (Batch 4020), Sample 402099 => Train Loss: 0.4233, Test Loss: 0.6809, Train Accuracy: 0.8951, Test Accuracy: 0.8573
# Epoch 59, (Batch 4090), Sample 409099 => Train Loss: 0.4215, Test Loss: 0.6767, Train Accuracy: 0.8963, Test Accuracy: 0.8567
# Epoch 60, (Batch 4160), Sample 416099 => Train Loss: 0.4176, Test Loss: 0.6769, Train Accuracy: 0.8977, Test Accuracy: 0.8577
# Epoch 60, (Batch 4160), Sample 416099 => Train Loss: 0.4146, Test Loss: 0.6746, Train Accuracy: 0.8984, Test Accuracy: 0.8583
# Epoch 61, (Batch 4230), Sample 423099 => Train Loss: 0.4130, Test Loss: 0.6714, Train Accuracy: 0.8986, Test Accuracy: 0.8577
# Epoch 62, (Batch 4300), Sample 430099 => Train Loss: 0.4100, Test Loss: 0.6699, Train Accuracy: 0.8987, Test Accuracy: 0.8583
# Epoch 63, (Batch 4370), Sample 437099 => Train Loss: 0.4072, Test Loss: 0.6693, Train Accuracy: 0.8989, Test Accuracy: 0.8577
# Epoch 63, (Batch 4370), Sample 437099 => Train Loss: 0.4050, Test Loss: 0.6674, Train Accuracy: 0.8986, Test Accuracy: 0.8580
# Epoch 64, (Batch 4440), Sample 444099 => Train Loss: 0.4027, Test Loss: 0.6662, Train Accuracy: 0.9004, Test Accuracy: 0.8573
# Epoch 65, (Batch 4510), Sample 451099 => Train Loss: 0.4012, Test Loss: 0.6637, Train Accuracy: 0.9001, Test Accuracy: 0.8587
# Epoch 65, (Batch 4510), Sample 451099 => Train Loss: 0.3980, Test Loss: 0.6632, Train Accuracy: 0.9010, Test Accuracy: 0.8593
# Epoch 66, (Batch 4580), Sample 458099 => Train Loss: 0.3965, Test Loss: 0.6596, Train Accuracy: 0.9006, Test Accuracy: 0.8587
# Epoch 67, (Batch 4650), Sample 465099 => Train Loss: 0.3945, Test Loss: 0.6586, Train Accuracy: 0.9010, Test Accuracy: 0.8580
# Epoch 68, (Batch 4720), Sample 472099 => Train Loss: 0.3914, Test Loss: 0.6554, Train Accuracy: 0.9023, Test Accuracy: 0.8593
# Epoch 68, (Batch 4720), Sample 472099 => Train Loss: 0.3899, Test Loss: 0.6602, Train Accuracy: 0.9023, Test Accuracy: 0.8590
# Epoch 69, (Batch 4790), Sample 479099 => Train Loss: 0.3868, Test Loss: 0.6555, Train Accuracy: 0.9024, Test Accuracy: 0.8600
# Epoch 70, (Batch 4860), Sample 486099 => Train Loss: 0.3846, Test Loss: 0.6557, Train Accuracy: 0.9027, Test Accuracy: 0.8610
# Epoch 70, (Batch 4860), Sample 486099 => Train Loss: 0.3823, Test Loss: 0.6493, Train Accuracy: 0.9039, Test Accuracy: 0.8613
# Epoch 71, (Batch 4930), Sample 493099 => Train Loss: 0.3805, Test Loss: 0.6486, Train Accuracy: 0.9044, Test Accuracy: 0.8610
# Epoch 72, (Batch 5000), Sample 500099 => Train Loss: 0.3786, Test Loss: 0.6487, Train Accuracy: 0.9040, Test Accuracy: 0.8597
# Epoch 73, (Batch 5070), Sample 507099 => Train Loss: 0.3764, Test Loss: 0.6473, Train Accuracy: 0.9049, Test Accuracy: 0.8617
# Epoch 73, (Batch 5070), Sample 507099 => Train Loss: 0.3747, Test Loss: 0.6448, Train Accuracy: 0.9049, Test Accuracy: 0.8600
# Epoch 74, (Batch 5140), Sample 514099 => Train Loss: 0.3729, Test Loss: 0.6468, Train Accuracy: 0.9051, Test Accuracy: 0.8617
# Epoch 75, (Batch 5210), Sample 521099 => Train Loss: 0.3724, Test Loss: 0.6481, Train Accuracy: 0.9053, Test Accuracy: 0.8597
# Epoch 75, (Batch 5210), Sample 521099 => Train Loss: 0.3687, Test Loss: 0.6414, Train Accuracy: 0.9063, Test Accuracy: 0.8613
# Epoch 76, (Batch 5280), Sample 528099 => Train Loss: 0.3671, Test Loss: 0.6432, Train Accuracy: 0.9064, Test Accuracy: 0.8610
# Epoch 77, (Batch 5350), Sample 535099 => Train Loss: 0.3664, Test Loss: 0.6429, Train Accuracy: 0.9069, Test Accuracy: 0.8607
# Epoch 78, (Batch 5420), Sample 542099 => Train Loss: 0.3632, Test Loss: 0.6378, Train Accuracy: 0.9074, Test Accuracy: 0.8600
# Epoch 78, (Batch 5420), Sample 542099 => Train Loss: 0.3631, Test Loss: 0.6405, Train Accuracy: 0.9076, Test Accuracy: 0.8640
# Epoch 79, (Batch 5490), Sample 549099 => Train Loss: 0.3598, Test Loss: 0.6348, Train Accuracy: 0.9083, Test Accuracy: 0.8600
# Epoch 80, (Batch 5560), Sample 556099 => Train Loss: 0.3579, Test Loss: 0.6370, Train Accuracy: 0.9090, Test Accuracy: 0.8617
# Epoch 80, (Batch 5560), Sample 556099 => Train Loss: 0.3561, Test Loss: 0.6355, Train Accuracy: 0.9086, Test Accuracy: 0.8620
# Epoch 81, (Batch 5630), Sample 563099 => Train Loss: 0.3548, Test Loss: 0.6363, Train Accuracy: 0.9113, Test Accuracy: 0.8630
# Epoch 82, (Batch 5700), Sample 570099 => Train Loss: 0.3533, Test Loss: 0.6335, Train Accuracy: 0.9106, Test Accuracy: 0.8633
# Epoch 83, (Batch 5770), Sample 577099 => Train Loss: 0.3511, Test Loss: 0.6311, Train Accuracy: 0.9103, Test Accuracy: 0.8630
# Epoch 83, (Batch 5770), Sample 577099 => Train Loss: 0.3491, Test Loss: 0.6307, Train Accuracy: 0.9114, Test Accuracy: 0.8620
# Epoch 84, (Batch 5840), Sample 584099 => Train Loss: 0.3489, Test Loss: 0.6337, Train Accuracy: 0.9130, Test Accuracy: 0.8633
# Epoch 85, (Batch 5910), Sample 591099 => Train Loss: 0.3460, Test Loss: 0.6287, Train Accuracy: 0.9121, Test Accuracy: 0.8640
# Epoch 85, (Batch 5910), Sample 591099 => Train Loss: 0.3447, Test Loss: 0.6279, Train Accuracy: 0.9117, Test Accuracy: 0.8633
# Epoch 86, (Batch 5980), Sample 598099 => Train Loss: 0.3431, Test Loss: 0.6272, Train Accuracy: 0.9117, Test Accuracy: 0.8637
# Epoch 87, (Batch 6050), Sample 605099 => Train Loss: 0.3424, Test Loss: 0.6272, Train Accuracy: 0.9127, Test Accuracy: 0.8643
# Epoch 88, (Batch 6120), Sample 612099 => Train Loss: 0.3410, Test Loss: 0.6268, Train Accuracy: 0.9124, Test Accuracy: 0.8627
# Epoch 88, (Batch 6120), Sample 612099 => Train Loss: 0.3384, Test Loss: 0.6237, Train Accuracy: 0.9136, Test Accuracy: 0.8647
# Epoch 89, (Batch 6190), Sample 619099 => Train Loss: 0.3368, Test Loss: 0.6218, Train Accuracy: 0.9137, Test Accuracy: 0.8647
# Epoch 90, (Batch 6260), Sample 626099 => Train Loss: 0.3362, Test Loss: 0.6244, Train Accuracy: 0.9131, Test Accuracy: 0.8647
# Epoch 90, (Batch 6260), Sample 626099 => Train Loss: 0.3338, Test Loss: 0.6205, Train Accuracy: 0.9140, Test Accuracy: 0.8653
# Epoch 91, (Batch 6330), Sample 633099 => Train Loss: 0.3331, Test Loss: 0.6196, Train Accuracy: 0.9139, Test Accuracy: 0.8647
# Epoch 92, (Batch 6400), Sample 640099 => Train Loss: 0.3313, Test Loss: 0.6192, Train Accuracy: 0.9147, Test Accuracy: 0.8660
# Epoch 93, (Batch 6470), Sample 647099 => Train Loss: 0.3298, Test Loss: 0.6191, Train Accuracy: 0.9151, Test Accuracy: 0.8660
# Epoch 93, (Batch 6470), Sample 647099 => Train Loss: 0.3282, Test Loss: 0.6165, Train Accuracy: 0.9159, Test Accuracy: 0.8653
# Epoch 94, (Batch 6540), Sample 654099 => Train Loss: 0.3268, Test Loss: 0.6184, Train Accuracy: 0.9160, Test Accuracy: 0.8660
# Epoch 95, (Batch 6610), Sample 661099 => Train Loss: 0.3253, Test Loss: 0.6158, Train Accuracy: 0.9157, Test Accuracy: 0.8667
# Epoch 95, (Batch 6610), Sample 661099 => Train Loss: 0.3240, Test Loss: 0.6143, Train Accuracy: 0.9160, Test Accuracy: 0.8677
# Epoch 96, (Batch 6680), Sample 668099 => Train Loss: 0.3228, Test Loss: 0.6148, Train Accuracy: 0.9163, Test Accuracy: 0.8663
# Epoch 97, (Batch 6750), Sample 675099 => Train Loss: 0.3217, Test Loss: 0.6123, Train Accuracy: 0.9170, Test Accuracy: 0.8660
# Epoch 98, (Batch 6820), Sample 682099 => Train Loss: 0.3217, Test Loss: 0.6164, Train Accuracy: 0.9171, Test Accuracy: 0.8650
# Epoch 98, (Batch 6820), Sample 682099 => Train Loss: 0.3190, Test Loss: 0.6106, Train Accuracy: 0.9169, Test Accuracy: 0.8673
# Epoch 99, (Batch 6890), Sample 689099 => Train Loss: 0.3192, Test Loss: 0.6161, Train Accuracy: 0.9171, Test Accuracy: 0.8660
# Epoch 100, (Batch 6960), Sample 696099 => Train Loss: 0.3162, Test Loss: 0.6113, Train Accuracy: 0.9183, Test Accuracy: 0.8673
# Epoch 100, (Batch 6960), Sample 696099 => Train Loss: 0.3148, Test Loss: 0.6091, Train Accuracy: 0.9189, Test Accuracy: 0.8683
# Total operations to reach comparable performance: 6050800000

# %%
plt.plot(range(len(train_loss_minib)), train_loss_minib, marker='o', label='Train Loss')
plt.plot(range(len(test_loss_minib)), test_loss_minib, marker='x', label='Test Loss')
plt.title('Log-Loss vs. Batch Number')
plt.xlabel('Batch Number')
plt.ylabel('Log-Loss')
plt.legend()

# %%
plt.plot(range(len(train_accuracy_minib)), train_accuracy_minib, marker='o', label='Train Accuracy')
plt.plot(range(len(test_accuracy_minib)), test_accuracy_minib, marker='x', label='Test Accuracy')
plt.title('Accuracy vs. Batch Number')
plt.xlabel('Batch Number')
plt.ylabel('Accuracy')
plt.legend()

# %% [raw]
# Batch gradient descent and stochastic gradient descent take the same number of operations compared to mini batch gradient descent which comparatively take more number of operations thereby increasing the computational complexity

# %%
outFile = 'HW4_aditi_model_weights.hdf5'

with h5py.File(outFile, 'w') as hf:
    hf.create_dataset('W', data = np.asarray(weights))
    hf.create_dataset('W', data = np.asarray(weights_sgd))
    hf.create_dataset('W', data = np.asarray(weights_minib))
    hf.create_dataset('b', data = np.asarray(bias))
    hf.create_dataset('b', data = np.asarray(bias_sgd))
    hf.create_dataset('b', data = np.asarray(bias_minib))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[137], line 5
#       3 with h5py.File(outFile, 'w') as hf:
#       4     hf.create_dataset('w', data = np.asarray(weights))
# ----> 5     hf.create_dataset('w', data = np.asarray(weights_sgd))
#       6     hf.create_dataset('w', data = np.asarray(weights_minib))
#       7     hf.create_dataset('b', data = np.asarray(bias))
#
# File ~\anaconda3\Lib\site-packages\h5py\_hl\group.py:183, in Group.create_dataset(self, name, shape, dtype, data, **kwds)
#     180         parent_path, name = name.rsplit(b'/', 1)
#     181         group = self.require_group(parent_path)
# --> 183 dsid = dataset.make_new_dset(group, shape, dtype, data, name, **kwds)
#     184 dset = dataset.Dataset(dsid)
#     185 return dset
#
# File ~\anaconda3\Lib\site-packages\h5py\_hl\dataset.py:163, in make_new_dset(parent, shape, dtype, data, name, chunks, compression, shuffle, fletcher32, maxshape, compression_opts, fillvalue, scaleoffset, track_times, external, track_order, dcpl, dapl, efile_prefix, virtual_prefix, allow_unknown_filter, rdcc_nslots, rdcc_nbytes, rdcc_w0)
#     160 else:
#     161     sid = h5s.create_simple(shape, maxshape)
# --> 163 dset_id = h5d.create(parent.id, name, tid, sid, dcpl=dcpl, dapl=dapl)
#     165 if (data is not None) and (not isinstance(data, Empty)):
#     166     dset_id.write(h5s.ALL, h5s.ALL, data)
#
# File h5py\\_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py\\_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py\\h5d.pyx:137, in h5py.h5d.create()
#
# ValueError: Unable to create dataset (name already exists)
